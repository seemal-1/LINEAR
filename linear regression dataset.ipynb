# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# %%
data
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0            16.0  3.000    13.00        8.0     2610        7.4
# 1             4.0  1.000     3.15        0.0     1700        9.9
# 2             8.0  1.500    13.00        5.0     2000        7.6
# 3             4.0  0.512     3.15        0.0     1400       11.0
# 4             4.0  1.000     3.15        0.0     1700        9.9
# ..            ...    ...      ...        ...      ...        ...
# 156         128.0  6.000    12.00       16.0     4080        8.4
# 157         128.0  6.000    20.00        8.0     3400        7.9
# 158          64.0  4.000    20.00       20.0     3000        6.8
# 159         128.0  6.000    20.00        8.0     3400        7.9
# 160          16.0  3.000    21.50       16.0     2700        8.4
#
# [161 rows x 14 columns]

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
1: Reading Data
# Out:
#   Cell In[23], line 1
#     1: Reading Data
#     ^
# SyntaxError: illegal target for annotation

# %%
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

data.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
data.head(2)
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
#
#    internal mem  ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.0    13.00        8.0     2610        7.4
# 1           4.0  1.0     3.15        0.0     1700        9.9

# %%
data.head(30)
# Out:
#     Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0          203   2357    10   135.0          5.2  424         8     1.350
# 1          880   1749    10   125.0          4.0  233         2     1.300
# 2           40   1916    10   110.0          4.7  312         4     1.200
# 3           99   1315    11   118.5          4.0  233         2     1.300
# 4          880   1749    11   125.0          4.0  233         2     1.300
# 5          947   2137    12   150.0          5.5  401         4     2.300
# 6          774   1238    13   134.1          4.0  233         2     1.200
# 7          947   2137    13   150.0          5.5  401         4     2.300
# 8           99   1315    14   118.5          4.0  233         2     1.300
# 9         1103   2580    15   145.0          5.1  432         4     2.500
# 10         289   2438    16   162.0          5.3  277         8     1.500
# 11         605   2006    16   161.0          5.5  200         8     1.400
# 12         622   2174    16   140.0          5.0  294         4     1.300
# 13        1058   2744    16   174.0          5.6  524         4     2.700
# 14        1103   2580    16   145.0          5.1  432         4     2.500
# 15        1120   1612    17   141.0          5.0  294         4     1.200
# 16         187   2258    17   150.0          5.0  441         4     2.300
# 17         315   2938    19   168.0          5.5  534         4     1.875
# 18        1120   1612    19   141.0          5.0  294         4     1.200
# 19         774   1238    20   134.1          4.0  233         2     1.200
# 20         289   2438    21   162.0          5.3  277         8     1.500
# 21         860   2392    22   147.0          5.2  282         8     1.400
# 22         990   2977    22   152.0          5.1  577         8     2.300
# 23        1058   2744    23   174.0          5.6  524         4     2.700
# 24         104   1942    24   139.2          4.7  469         4     2.150
# 25         776   1390    24   146.0          5.0  220         4     1.200
# 26         605   2006    24   161.0          5.5  200         8     1.400
# 27         315   2938    25   168.0          5.5  534         4     1.875
# 28         776   1390    25   146.0          5.0  220         4     1.200
# 29          10   1950    26   118.0          5.0  187         4     1.300
#
#     internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0           16.0  3.000    13.00        8.0     2610        7.4
# 1            4.0  1.000     3.15        0.0     1700        9.9
# 2            8.0  1.500    13.00        5.0     2000        7.6
# 3            4.0  0.512     3.15        0.0     1400       11.0
# 4            4.0  1.000     3.15        0.0     1700        9.9
# 5           16.0  2.000    16.00        8.0     2500        9.5
# 6            8.0  1.000     2.00        0.0     1560       11.7
# 7           16.0  2.000    16.00        8.0     2500        9.5
# 8            4.0  0.512     3.15        0.0     1400       11.0
# 9           16.0  2.000    16.00        2.0     2800        8.1
# 10          32.0  4.000    13.00        8.0     4000        7.7
# 11           4.0  1.000     5.00        0.0     2500        8.9
# 12          16.0  1.000    13.00        5.0     2000        8.2
# 13          32.0  3.000    16.00        3.7     3000        8.3
# 14          16.0  2.000    16.00        2.0     2800        8.1
# 15           8.0  1.500     8.00        1.2     2040       10.0
# 16          16.0  2.000    13.00        2.0     2300       10.0
# 17          32.0  4.000    12.30        8.0     3450        8.5
# 18           8.0  1.500     8.00        1.2     2040       10.0
# 19           8.0  1.000     2.00        0.0     1560       11.7
# 20          32.0  4.000    13.00        8.0     4000        7.7
# 21          32.0  3.000    13.00       16.0     2900        7.7
# 22          32.0  4.000    12.00        5.0     3000        7.9
# 23          32.0  3.000    16.00        3.7     3000        8.3
# 24          16.0  2.000    16.00        4.0     2200       10.3
# 25           8.0  1.000     5.00        5.0     1905        8.8
# 26           4.0  1.000     5.00        0.0     2500        8.9
# 27          32.0  4.000    12.30        8.0     3450        8.5
# 28           8.0  1.000     5.00        5.0     1905        8.8
# 29           8.0  1.000     8.00        2.0     2000        6.4

# %%
data.tail()
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem  ram  RearCam  Front_Cam  battery  thickness
# 156         128.0  6.0     12.0       16.0     4080        8.4
# 157         128.0  6.0     20.0        8.0     3400        7.9
# 158          64.0  4.0     20.0       20.0     3000        6.8
# 159         128.0  6.0     20.0        8.0     3400        7.9
# 160          16.0  3.0     21.5       16.0     2700        8.4

# %%
data.shape
# Out:
# (161, 14)

# %%
data.tail(20)
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 141         701    628  1274   102.9         2.20  128         0     0.000
# 142        1161   2508  1530   152.0         5.20  424         4     2.500
# 143        1161   2508  1584   152.0         5.20  424         4     2.500
# 144          32   1921  1781   179.0         6.00  184         4     1.300
# 145          32   1921  1862   179.0         6.00  184         4     1.300
# 146        1137   3102  2071   180.0         5.50  806         8     1.750
# 147        1137   3102  2088   180.0         5.50  806         8     1.750
# 148         851   3055  2106   158.0         5.50  401         4     1.875
# 149         826    614  2159    69.8         1.40  129         0     0.000
# 150         826    614  2171    69.8         1.40  129         0     0.000
# 151         851   3055  2173   158.0         5.50  401         4     1.875
# 152         290   4361  3248   238.0         5.70  515         8     1.950
# 153         290   4361  3291   238.0         5.70  515         8     1.950
# 154        1131   2536  3619   202.0         6.00  367         8     1.500
# 155        1206   3551  4408   178.0         5.46  538         4     1.875
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# 141         0.256  0.128      1.3        0.0      950       18.5
# 142        16.000  3.000     20.7        2.2     3100        7.3
# 143        16.000  3.000     20.7        2.2     3100        7.3
# 144         8.000  1.000     13.0        8.0     2580        8.0
# 145         8.000  1.000     13.0        8.0     2580        8.0
# 146        32.000  3.000     23.0        5.1     3430        7.8
# 147        32.000  3.000     23.0        5.1     3430        7.8
# 148        64.000  6.000     16.0        8.0     3000        7.4
# 149         0.000  0.004      0.0        0.0      800       14.1
# 150         0.000  0.004      0.0        0.0      800       14.1
# 151        64.000  6.000     16.0        8.0     3000        7.4
# 152       128.000  6.000     12.0        8.0     7000        7.4
# 153       128.000  6.000     12.0        8.0     7000        7.4
# 154        16.000  3.000     21.5       16.0     2700        8.4
# 155       128.000  6.000     12.0       16.0     4080        8.4
# 156       128.000  6.000     12.0       16.0     4080        8.4
# 157       128.000  6.000     20.0        8.0     3400        7.9
# 158        64.000  4.000     20.0       20.0     3000        6.8
# 159       128.000  6.000     20.0        8.0     3400        7.9
# 160        16.000  3.000     21.5       16.0     2700        8.4

# %%
data.sample()
# Out:
#     Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 43         907   2087    40   147.0          5.0  294         4       1.3
#
#     internal mem  ram  RearCam  Front_Cam  battery  thickness
# 43          32.0  3.0      8.0        5.0     2450        7.6

# %%
data.sample(30)
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 134         497   2266   615   112.0         5.00  294         8     1.400
# 42          162   1843    38   133.5         4.50  218         4     1.300
# 143        1161   2508  1584   152.0         5.20  424         4     2.500
# 86         1026    791   114    66.0         1.50  121         1     0.208
# 99          841   1511   198   134.0         4.50  221         4     1.200
# 28          776   1390    25   146.0         5.00  220         4     1.200
# 90          237   1646   141   404.0         8.00  160         4     1.200
# 142        1161   2508  1530   152.0         5.20  424         4     2.500
# 103        1080   2343   206   158.0         5.10  432         4     2.500
# 131        1089   1357   564   165.0         4.66  200         4     1.200
# 39          860   2392    36   147.0         5.20  282         8     1.400
# 139         377   2409  1043   160.0         5.00  441         4     2.300
# 38          575   1777    36   174.0         5.50  178         4     1.300
# 43          907   2087    40   147.0         5.00  294         4     1.300
# 92          131   1831   156   154.0         5.00  294         4     1.200
# 55          575   1777    45   174.0         5.50  178         4     1.300
# 78         1221   2714   101   156.0         5.50  401         8     1.350
# 105         827    833   213    78.4         2.40  166         0     0.000
# 67           56   2044    82   310.0         8.00  283         8     2.000
# 136         301   2445   678   183.0         5.00  294         4     1.300
# 119         460   1734   378   118.0         4.00  245         4     1.200
# 144          32   1921  1781   179.0         6.00  184         4     1.300
# 29           10   1950    26   118.0         5.00  187         4     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# 50          804   1741    43   145.0         4.50  245         4     1.200
# 112          30   2975   307   149.0         5.50  534         8     1.600
# 147        1137   3102  2088   180.0         5.50  806         8     1.750
# 130        1089   1357   523   165.0         4.66  200         4     1.200
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0            16.0  3.000    13.00        8.0     2610        7.4
# 134           8.0  1.000     8.00        8.0     1900        6.3
# 42            8.0  1.000     5.00        0.0     1600       10.1
# 143          16.0  3.000    20.70        2.2     3100        7.3
# 86            0.0  0.004     0.00        0.0      800       13.2
# 99            8.0  0.512     5.00        0.0     1830        9.2
# 28            8.0  1.000     5.00        5.0     1905        8.8
# 90            8.0  1.000     5.00        5.0     4500        9.0
# 142          16.0  3.000    20.70        2.2     3100        7.3
# 103          16.0  2.000    16.00        2.0     2800        8.9
# 131           0.0  0.000     5.00        0.0     2600       11.6
# 39           32.0  3.000    13.00       16.0     2900        7.7
# 139          32.0  2.000     4.00        5.0     2600        9.4
# 38            4.0  0.512     5.00        0.0     2250        9.2
# 43           32.0  3.000     8.00        5.0     2450        7.6
# 92            8.0  1.000    13.00        5.0     2100        8.4
# 55            4.0  0.512     5.00        0.0     2250        9.2
# 78           16.0  2.000    13.00        5.0     2300        5.1
# 105           0.0  0.008     0.00        0.0     1100       12.9
# 67            8.0  2.000     5.00        2.0     4060        7.3
# 136          32.0  3.000     8.00        5.0     4000        8.5
# 119           4.0  0.512     5.00        2.0     1730       10.9
# 144           8.0  1.000    13.00        8.0     2580        8.0
# 29            8.0  1.000     8.00        2.0     2000        6.4
# 4             4.0  1.000     3.15        0.0     1700        9.9
# 50            8.0  1.000     5.00        0.0     2390       12.3
# 112          32.0  3.000    16.00        8.0     3000        7.0
# 147          32.0  3.000    23.00        5.1     3430        7.8
# 130           0.0  0.000     5.00        0.0     2600       11.6
# 157         128.0  6.000    20.00        8.0     3400        7.9

# %%
data.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# min    121.000000    0.000000    0.000000      0.000000    0.000000
# 25%    233.000000    4.000000    1.200000      8.000000    1.000000
# 50%    294.000000    4.000000    1.400000     16.000000    2.000000
# 75%    428.000000    8.000000    1.875000     32.000000    3.000000
# max    806.000000    8.000000    2.700000    128.000000    6.000000
#
#           RearCam   Front_Cam      battery   thickness
# count  161.000000  161.000000   161.000000  161.000000
# mean    10.378261    4.503106  2842.111801    8.921739
# std      6.181585    4.342053  1366.990838    2.192564
# min      0.000000    0.000000   800.000000    5.100000
# 25%      5.000000    0.000000  2040.000000    7.600000
# 50%     12.000000    5.000000  2800.000000    8.400000
# 75%     16.000000    8.000000  3240.000000    9.800000
# max     23.000000   20.000000  9500.000000   18.500000

# %%
2: Data Cleaning

# %%
import pandas as pd
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# %%
data.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Separate numeric and non-numeric columns
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

# Fill missing values in numeric columns with the mean
numeric_cols.fillna(numeric_cols.mean(), inplace=True)   # Numerical features
#non_numeric_cols.fillna(non_numeric_cols.mode(), inplace=True) # Categorical features


# Combine back with non-numeric columns
data = pd.concat([numeric_cols, non_numeric_cols], axis=1)

# Check for any remaining missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
import pandas as pd
import numpy as np

# Assuming 'data' is your dataframe
# Separate numeric and non-numeric columns
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

# Fill missing values in numeric columns with the mean
numeric_cols.fillna(numeric_cols.mean(), inplace=True)   # Numerical features

# Fill missing values in non-numeric columns (categorical) with the mode (most frequent value)
for col in non_numeric_cols.columns:
    non_numeric_cols[col].fillna(non_numeric_cols[col].mode()[0], inplace=True)  # Categorical features

# Combine back with non-numeric columns
data = pd.concat([numeric_cols, non_numeric_cols], axis=1)

# Check for any remaining missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
data.shape
# Out:
# (161, 14)

# %%
Removal: Deleting rows with missing values.

# %%
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')
data.isnull().sum()
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
data.shape
# Out:
# (161, 14)

# %%
data.dropna(inplace=True)


missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Product_id      0
# Price           0
# Sale            0
# weight          0
# resoloution     0
# ppi             0
# cpu core        0
# cpu freq        0
# internal mem    0
# ram             0
# RearCam         0
# Front_Cam       0
# battery         0
# thickness       0
# dtype: int64

# %%
data.shape
# Out:
# (161, 14)

# %%
Removing Duplicates

# %%
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')
data.shape
# Out:
# (161, 14)

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (161, 14)

# %%
3: Outlier Detection and Removal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# Checking the structure of the dataset
#print(data.info())
data.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# min    121.000000    0.000000    0.000000      0.000000    0.000000
# 25%    233.000000    4.000000    1.200000      8.000000    1.000000
# 50%    294.000000    4.000000    1.400000     16.000000    2.000000
# 75%    428.000000    8.000000    1.875000     32.000000    3.000000
# max    806.000000    8.000000    2.700000    128.000000    6.000000
#
#           RearCam   Front_Cam      battery   thickness
# count  161.000000  161.000000   161.000000  161.000000
# mean    10.378261    4.503106  2842.111801    8.921739
# std      6.181585    4.342053  1366.990838    2.192564
# min      0.000000    0.000000   800.000000    5.100000
# 25%      5.000000    0.000000  2040.000000    7.600000
# 50%     12.000000    5.000000  2800.000000    8.400000
# 75%     16.000000    8.000000  3240.000000    9.800000
# max     23.000000   20.000000  9500.000000   18.500000

# %%
0.25-1.5*0.5
# Out:
# -0.5

# %%
0.75 + 1.5 * 0.5
# Out:
# 1.5

# %%
# Identify numeric columns
numeric_cols = data.select_dtypes(include=[np.number])

# Calculate IQR
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1

# Filter out outliers        # 0.25-1.5*0.5 = -0.5                      #  0.75 + 1.5 * 0.5 = 1.5

data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]

# Visualizing the data before and after outlier removal
plt.figure(figsize=(20, 6))

# Box plot before removing outliers
plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")

# # Box plot after removing outliers
# plt.subplot(1, 2, 2)
# data_cleaned.select_dtypes(include=[np.number]).boxplot()
# plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))

# Box plot after removing outliers
plt.subplot(1, 2, 2)
data_cleaned.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (113, 14)

# %%
data_cleaned.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
4. Data Transformation

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# Separate numeric and non-numeric columns
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

# Apply MinMaxScaler to the numeric columns
scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

# Convert the scaled numeric data back to a DataFrame
scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

# Combine the scaled numeric columns with the non-numeric columns
scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

# Check the shape of the scaled data
print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (161, 14)
#
# ************************************************************
#    Product_id     Price      Sale    weight  resoloution       ppi  cpu core  \
# 0    0.145222  0.465172  0.000000  0.100437     0.351852  0.442336      1.00
# 1    0.654628  0.302909  0.000000  0.085881     0.240741  0.163504      0.25
# 2    0.022573  0.347478  0.000000  0.064047     0.305556  0.278832      0.50
# 3    0.066968  0.187083  0.000102  0.076419     0.240741  0.163504      0.25
# 4    0.654628  0.302909  0.000102  0.085881     0.240741  0.163504      0.25
#
#    cpu freq  internal mem       ram   RearCam  Front_Cam   battery  thickness
# 0  0.500000       0.12500  0.500000  0.565217       0.40  0.208046   0.171642
# 1  0.481481       0.03125  0.166667  0.136957       0.00  0.103448   0.358209
# 2  0.444444       0.06250  0.250000  0.565217       0.25  0.137931   0.186567
# 3  0.481481       0.03125  0.085333  0.136957       0.00  0.068966   0.440299
# 4  0.481481       0.03125  0.166667  0.136957       0.00  0.103448   0.358209

# %%
Standardization

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# Separate numeric and non-numeric columns
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])

# Apply StandardScaler to the numeric columns
scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)

# Convert the scaled numeric data back to a DataFrame
scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)

# Combine the scaled numeric columns with the non-numeric columns
scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)

# Check the shape of the scaled data
print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (161, 14)
#
# ************************************************************
#    Product_id     Price      Sale    weight  resoloution       ppi  cpu core  \
# 0   -1.153783  0.184649 -0.396590 -0.382572    -0.006602  0.661751  1.289952
# 1    0.499156 -0.609294 -0.396590 -0.490564    -0.803808 -0.759303 -1.172684
# 2   -1.551758 -0.391221 -0.396590 -0.652552    -0.338771 -0.171538 -0.351805
# 3   -1.407705 -1.176024 -0.395942 -0.560759    -0.803808 -0.759303 -1.172684
# 4    0.499156 -0.609294 -0.395942 -0.490564    -0.803808 -0.759303 -1.172684
#
#    cpu freq  internal mem       ram   RearCam  Front_Cam   battery  thickness
# 0 -0.255608     -0.296070  0.495385  0.425444   0.807868 -0.170327  -0.696211
# 1 -0.339231     -0.713968 -0.750857 -1.172970  -1.040327 -0.838100   0.447564
# 2 -0.506479     -0.574669 -0.439297  0.425444   0.114795 -0.617955  -0.604709
# 3 -0.339231     -0.713968 -1.054940 -1.172970  -1.040327 -1.058245   0.950825
# 4 -0.339231     -0.713968 -0.750857 -1.172970  -1.040327 -0.838100   0.447564

# %%
5: One-Hot Encoding

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')
data.head(2)
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
#
#    internal mem  ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.0    13.00        8.0     2610        7.4
# 1           4.0  1.0     3.15        0.0     1700        9.9

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# Separate numeric and non-numeric columns
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# Convert categorical columns using pd.get_dummies
data1 = pd.get_dummies(cat_features)
data1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# Separate numeric and non-numeric columns
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']

# Convert categorical columns using pd.get_dummies
data1 = pd.get_dummies(data, columns=cat_features)

# Combine the scaled numeric columns with the non-numeric columns (if any)
scaled_data = pd.concat([data, data1], axis=1)

# Check the shape of the scaled data
print(scaled_data.shape)
print()
print('*' * 70)

scaled_data.head()
# Out:
# (161, 28)
#
# **********************************************************************
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  ...  resoloution  ppi  cpu core  cpu freq  \
# 0          16.0  3.000  ...          5.2  424         8      1.35
# 1           4.0  1.000  ...          4.0  233         2      1.30
# 2           8.0  1.500  ...          4.7  312         4      1.20
# 3           4.0  0.512  ...          4.0  233         2      1.30
# 4           4.0  1.000  ...          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9
#
# [5 rows x 28 columns]

# %%
data.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness'],
#       dtype='object')

# %%
scaled_data.columns
# Out:
# Index(['Product_id', 'Price', 'Sale', 'weight', 'resoloution', 'ppi',
#        'cpu core', 'cpu freq', 'internal mem', 'ram', 'RearCam', 'Front_Cam',
#        'battery', 'thickness', 'Product_id', 'Price', 'Sale', 'weight',
#        'resoloution', 'ppi', 'cpu core', 'cpu freq', 'internal mem', 'ram',
#        'RearCam', 'Front_Cam', 'battery', 'thickness'],
#       dtype='object')

# %%
data1.head()
# Out:
#    Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0         203   2357    10   135.0          5.2  424         8      1.35
# 1         880   1749    10   125.0          4.0  233         2      1.30
# 2          40   1916    10   110.0          4.7  312         4      1.20
# 3          99   1315    11   118.5          4.0  233         2      1.30
# 4         880   1749    11   125.0          4.0  233         2      1.30
#
#    internal mem    ram  RearCam  Front_Cam  battery  thickness
# 0          16.0  3.000    13.00        8.0     2610        7.4
# 1           4.0  1.000     3.15        0.0     1700        9.9
# 2           8.0  1.500    13.00        5.0     2000        7.6
# 3           4.0  0.512     3.15        0.0     1400       11.0
# 4           4.0  1.000     3.15        0.0     1700        9.9

# %%
6: Data Reduction¶

# %%
scaled_data.shape
# Out:
# (161, 28)

# %%
7: Handling Imbalanced Data
Resampling Techniques
Oversampling

# %%
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

data. alive.value_counts(True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10528\2924905910.py in ?()
#       1 data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')
#       2
# ----> 3 data. alive.value_counts(True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'alive'

# %%
data.shape
# Out:
# (161, 14)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv(r'C:/Users/HP/Downloads/archive (2)/Cellphone.csv')

# Handle missing values (if any)
data.fillna(data.mean(numeric_only=True), inplace=True)

# Separate categorical and numeric columns
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
numeric_features = [feature for feature in data.columns if data[feature].dtype != 'O']

# Convert categorical columns using pd.get_dummies
data = pd.get_dummies(data, columns=cat_features)

# Standardize the numeric columns
scaler = StandardScaler()
data[numeric_features] = scaler.fit_transform(data[numeric_features].values)

# Convert the target variable to categorical if necessary
# Assuming 'alive' is the target column, you may need to binarize or discretize it
if data['price'].dtype != 'int64' and data['price'].dtype != 'bool':
    # Example: Binarize 'alive' if it's not already binary
    # Replace this logic with appropriate binning or thresholding based on your dataset
    data['price'] = (data['price'] > 0.5).astype(int)

# Separate features and target
X = data.drop(columns=['price'])  # Replace 'alive' with your target column
y = data['price']  # Replace 'alive' with your target column

# Encode the target variable if it's not already encoded
if y.dtype == 'O':
    le = LabelEncoder()
    y = le.fit_transform(y)

print(X.shape, y.shape)

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Combine resampled data
data_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns), pd.DataFrame(y_resampled, columns=['alive'])], axis=1)
data_resampled.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[120], line 27
#      23 data[numeric_features] = scaler.fit_transform(data[numeric_features].values)
#      25 # Convert the target variable to categorical if necessary
#      26 # Assuming 'alive' is the target column, you may need to binarize or discretize it
# ---> 27 if data['price'].dtype != 'int64' and data['price'].dtype != 'bool':
#      28     # Example: Binarize 'alive' if it's not already binary
#      29     # Replace this logic with appropriate binning or thresholding based on your dataset
#      30     data['price'] = (data['price'] > 0.5).astype(int)
#      32 # Separate features and target
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'price'

# %%
data_resampled.price.value_counts(True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 data_resampled.price.value_counts(True)
#
# NameError: name 'data_resampled' is not defined

# %%
data_resampled.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 data_resampled.shape
#
# NameError: name 'data_resampled' is not defined

# %%
8: Splitting Data

# %%
from sklearn.model_selection import train_test_split
data = pd.read_csv('echocardiogram.csv')

X = data.drop('alive', axis=1)
y = data['alive']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((93, 12), (40, 12), (93,), (40,))
